# %% [markdown]
# ### 常數

# %%
# TEST_VIDEO = "../../../../resources/video/20240619/2/work2.mp4"
TEST_VIDEO = "./test_video/video_in.mp4"

# %% [markdown]
# ### 套件

# %%
from src.server_api import get_video_json_result

# %% [markdown]
# ### 主程式

# %%
for key, val in get_video_json_result(TEST_VIDEO).items():
    print(key, val, sep="\t", end="\t")

    if key == "extra 1":
        if val == "FREQUENTLY_OR_CONSTANTLY":
            print("3")
        elif val == "OCCASIONALLY":
            print("1")
        else:
            print("0")
    elif key == "extra 2":
        if val == "FREQUENTLY_OR_CONSTANTLY":
            print("3")
        elif val == "OCCASIONALLY":
            print("1")
        else:
            print("0")
    elif key == "extra 3":
        if val == "FREQUENTLY_OR_CONSTANTLY":
            print("1")
        elif val == "OCCASIONALLY":
            print("0.5")
        else:
            print("0")
    elif key == "extra 4":
        if val == "FREQUENTLY_OR_CONSTANTLY":
            print("2")
        elif val == "OCCASIONALLY":
            print("1")
        else:
            print("0")
    else:
        print("")
# Out:
# f:\repos\nodejs-project\kim-flutter-nodejs\projects\server-client\python\video-analyze-server\venv\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Can't receive frame (stream end?). Exiting ...
# extra scores: [0.  3.  0.5 2. ]
# sum of extra scores: 5.5
# extra scores: [0.  3.  0.5 2. ]
# sum of extra scores: 5.5
# start	A5
# end	A5
# extra 1	RARELY	0
# extra 2	FREQUENTLY_OR_CONSTANTLY	3
# extra 3	OCCASIONALLY	0.5
# extra 4	FREQUENTLY_OR_CONSTANTLY	2
# pose score	20
# extra score	5.5
# total score	25.5
