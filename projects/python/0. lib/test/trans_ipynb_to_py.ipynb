# %%
IPYNB_FOLDER = "./src/"
OUTPUT_FOLDER = "./output/src/"

# %%
from pathlib import Path
import subprocess

# %%
result = subprocess.check_output("dir", shell=True, text=True, encoding="utf-8")
print(result)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 result = subprocess.check_output("dir", shell=True, text=True, encoding="utf-8")
#       2 print(result)
#
# File f:\repos\nodejs-project\kim-flutter-nodejs\projects\python\0. lib\test\venv\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File f:\repos\nodejs-project\kim-flutter-nodejs\projects\python\0. lib\test\venv\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
# ...

# %%
ipynb_folder = Path(IPYNB_FOLDER)
output_folder = Path(OUTPUT_FOLDER)

# %%
for pth in list(ipynb_folder.rglob("*.ipynb")):
    pth = str(pth)
    os.system("jupyter nbconvert --to python " + pth)
# Out:
# src\calculate.ipynb
# src\json_to_pose\base.ipynb
# src\json_to_pose\values.ipynb
# src\mediapipe_lib\base.ipynb
# src\mediapipe_lib\calculator.ipynb
# src\mediapipe_lib\value.ipynb
# src\utils\plot_painter.ipynb
# src\utils\process_data.ipynb
