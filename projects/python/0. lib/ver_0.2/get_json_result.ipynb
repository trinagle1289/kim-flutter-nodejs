# %% [markdown]
# ##### 常數

# %%
VIDEO = "../../../../resources/video/20240717/2/score_0.mp4"  # 影片路徑
MODEL = "./models/BlazePose/pose_landmarker_full.task"  # 模型路徑

# %% [markdown]
# #### 套件

# %%
from src.server_api import get_video_json_result

# %% [markdown]
# #### 開始測試

# %%
results = get_video_json_result(VIDEO)
for key, val in results.items():
    print(key, val, sep='  \t')
# Out:
# f:\repos\kim-flutter-nodejs\projects\python\0. lib\ver_0.2\venv\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Can't receive frame (stream end?). Exiting ...
# extra scores: [3. 3. 0. 0.]
# sum of extra scores: 6.0
# extra scores: [3. 3. 0. 0.]
# sum of extra scores: 6.0
# start  	A1
# end  	A1
# extra 1  	FREQUENTLY_OR_CONSTANTLY
# extra 2  	FREQUENTLY_OR_CONSTANTLY
# extra 3  	RARELY
# extra 4  	RARELY
# pose score  	0
# extra score  	6.0
# total score  	6.0
