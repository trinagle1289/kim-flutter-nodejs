# %%
IPYNB_FOLDER = "./src/"
OUTPUT_FOLDER = "./output/"

# %%
from pathlib import Path
import subprocess

# %%
folder_in = Path(IPYNB_FOLDER)
folder_out = Path(OUTPUT_FOLDER)

# %%
# 建立 py 檔案
for pth in list(folder_in.rglob("*.ipynb")):
    cmd = f"jupyter nbconvert --to python {pth}"
    result = subprocess.run(cmd, shell=True, text=True)
    print(f"finish cmd: {result.args}\t| return: {result.returncode}")

print("Finish creating all python files.")
# Out:
# finish cmd: jupyter nbconvert --to python src\calculate.ipynb	| return: 0
# finish cmd: jupyter nbconvert --to python src\draw_template.ipynb	| return: 0
# finish cmd: jupyter nbconvert --to python src\server_api.ipynb	| return: 0
# finish cmd: jupyter nbconvert --to python src\mp_lib\base.ipynb	| return: 0
# finish cmd: jupyter nbconvert --to python src\mp_lib\calculator.ipynb	| return: 0
# finish cmd: jupyter nbconvert --to python src\mp_lib\value.ipynb	| return: 0
# finish cmd: jupyter nbconvert --to python src\utils\cv_lib.ipynb	| return: 0
# finish cmd: jupyter nbconvert --to python src\utils\plot_painter.ipynb	| return: 0
# Finish creating all python files.

# %%
for pth in list(folder_in.rglob("*.py")):
    # 建立資料夾
    cmd = f"mkdir {folder_out / pth.parent}"
    result = subprocess.run(cmd, shell=True, text=True)
    print(f"finish cmd: {result.args}\t\t\t\t\t| return: {result.returncode}")
    # 複製 py 檔案
    cmd = f"copy {pth} {folder_out / pth}"
    result = subprocess.run(cmd, shell=True, text=True)
    print(f"finish cmd: {result.args}\t| return: {result.returncode}\n")

print("All Python files have been copied to the output folder")
# Out:
# finish cmd: mkdir output\src					| return: 1
# finish cmd: copy src\calculate.py output\src\calculate.py	| return: 0
#
# finish cmd: mkdir output\src					| return: 1
# finish cmd: copy src\draw_template.py output\src\draw_template.py	| return: 0
#
# finish cmd: mkdir output\src					| return: 1
# finish cmd: copy src\server_api.py output\src\server_api.py	| return: 0
#
# finish cmd: mkdir output\src\mp_lib					| return: 1
# finish cmd: copy src\mp_lib\base.py output\src\mp_lib\base.py	| return: 0
#
# finish cmd: mkdir output\src\mp_lib					| return: 1
# finish cmd: copy src\mp_lib\calculator.py output\src\mp_lib\calculator.py	| return: 0
#
# finish cmd: mkdir output\src\mp_lib					| return: 1
# finish cmd: copy src\mp_lib\value.py output\src\mp_lib\value.py	| return: 0
#
# finish cmd: mkdir output\src\utils					| return: 1
# finish cmd: copy src\utils\cv_lib.py output\src\utils\cv_lib.py	| return: 0
#
# finish cmd: mkdir output\src\utils					| return: 1
# finish cmd: copy src\utils\plot_painter.py output\src\utils\plot_painter.py	| return: 0
#
# All Python files have been copied to the output folder
