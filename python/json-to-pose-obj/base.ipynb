# %%
# TEST JSON FILE
json_pth = "json/front/A1-A3.json"

# %%
import json
import numpy as np

# %%
class PoseBase:
    json_data: list = []

    def __init__(self, json_file_path: str) -> None:
        with open(json_file_path) as f:
            self.json_data = json.load(f)
        pass

    def __len__(self) -> None:
        pass
